# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('/home/sk-ji/Downloads/abalone.data')
# idx = pd.read_csv('/home/sk-ji/Downloads/abalone.names')
#idx 
df
# Out:
#       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of       M  0.455  0.365  0.095   0.514  0.2245   0.101    0.15  15
# 0     M  0.350  0.265  0.090  0.2255  0.0995  0.0485  0.0700   7
# 1     F  0.530  0.420  0.135  0.6770  0.2565  0.1415  0.2100   9
# 2     M  0.440  0.365  0.125  0.5160  0.2155  0.1140  0.1550  10
# 3     I  0.330  0.255  0.080  0.2050  0.0895  0.0395  0.0550   7
# 4     I  0.425  0.300  0.095  0.3515  0.1410  0.0775  0.1200   8
# ...  ..    ...    ...    ...     ...     ...     ...     ...  ..
# 4171  F  0.565  0.450  0.165  0.8870  0.3700  0.2390  0.2490  11
# 4172  M  0.590  0.440  0.135  0.9660  0.4390  0.2145  0.2605  10
# 4173  M  0.600  0.475  0.205  1.1760  0.5255  0.2875  0.3080   9
# 4174  F  0.625  0.485  0.150  1.0945  0.5310  0.2610  0.2960  10
# 4175  M  0.710  0.555  0.195  1.9485  0.9455  0.3765  0.4950  12
#
# [4176 rows x 9 columns]>

# %%
df.describe()
# Out:
#              0.455        0.365        0.095        0.514      0.2245  \
# count  4176.000000  4176.000000  4176.000000  4176.000000  4176.00000
# mean      0.524009     0.407892     0.139527     0.828818     0.35940
# std       0.120103     0.099250     0.041826     0.490424     0.22198
# min       0.075000     0.055000     0.000000     0.002000     0.00100
# 25%       0.450000     0.350000     0.115000     0.441500     0.18600
# 50%       0.545000     0.425000     0.140000     0.799750     0.33600
# 75%       0.615000     0.480000     0.165000     1.153250     0.50200
# max       0.815000     0.650000     1.130000     2.825500     1.48800
#
#              0.101         0.15           15
# count  4176.000000  4176.000000  4176.000000
# mean      0.180613     0.238852     9.932471
# std       0.109620     0.139213     3.223601
# min       0.000500     0.001500     1.000000
# 25%       0.093375     0.130000     8.000000
# 50%       0.171000     0.234000     9.000000
# 75%       0.253000     0.329000    11.000000
# max       0.760000     1.005000    29.000000

# %%
df.shape
# Out:
# (4176, 9)

# %%
df.dtypes
# Out:
# M          object
# 0.455     float64
# 0.365     float64
# 0.095     float64
# 0.514     float64
# 0.2245    float64
# 0.101     float64
# 0.15      float64
# 15          int64
# dtype: object

# %%
column_name = []
for i in range(1,10):
    col = "column"
    col1 = col+str(i)
    column_name.append(col1)
    
column_name
# Out:
# ['column1',
#  'column2',
#  'column3',
#  'column4',
#  'column5',
#  'column6',
#  'column7',
#  'column8',
#  'column9']

# %%
df.columns = column_name

# %%
df
# Out:
#      column1  column2  column3  column4  column5  column6  column7  column8  \
# 0          M    0.350    0.265    0.090   0.2255   0.0995   0.0485   0.0700
# 1          F    0.530    0.420    0.135   0.6770   0.2565   0.1415   0.2100
# 2          M    0.440    0.365    0.125   0.5160   0.2155   0.1140   0.1550
# 3          I    0.330    0.255    0.080   0.2050   0.0895   0.0395   0.0550
# 4          I    0.425    0.300    0.095   0.3515   0.1410   0.0775   0.1200
# ...      ...      ...      ...      ...      ...      ...      ...      ...
# 4171       F    0.565    0.450    0.165   0.8870   0.3700   0.2390   0.2490
# 4172       M    0.590    0.440    0.135   0.9660   0.4390   0.2145   0.2605
# 4173       M    0.600    0.475    0.205   1.1760   0.5255   0.2875   0.3080
# 4174       F    0.625    0.485    0.150   1.0945   0.5310   0.2610   0.2960
# 4175       M    0.710    0.555    0.195   1.9485   0.9455   0.3765   0.4950
#
#       column9
# 0           7
# 1           9
# 2          10
# 3           7
# 4           8
# ...       ...
# 4171       11
# 4172       10
# 4173        9
# 4174       10
# 4175       12
#
# [4176 rows x 9 columns]

# %%
sns.pairplot(data=df)

# %%
df.corr()
# Out:
#           column2   column3   column4   column5   column6   column7   column8  \
# column2  1.000000  0.986813  0.827552  0.925255  0.897905  0.903010  0.897697
# column3  0.986813  1.000000  0.833705  0.925452  0.893159  0.899726  0.905328
# column4  0.827552  0.833705  1.000000  0.819209  0.774957  0.798293  0.817326
# column5  0.925255  0.925452  0.819209  1.000000  0.969403  0.966372  0.955351
# column6  0.897905  0.893159  0.774957  0.969403  1.000000  0.931956  0.882606
# column7  0.903010  0.899726  0.798293  0.966372  0.931956  1.000000  0.907647
# column8  0.897697  0.905328  0.817326  0.955351  0.882606  0.907647  1.000000
# column9  0.557123  0.575005  0.558109  0.540818  0.421256  0.504274  0.628031
#
#           column9
# column2  0.557123
# column3  0.575005
# column4  0.558109
# column5  0.540818
# column6  0.421256
# column7  0.504274
# column8  0.628031
# column9  1.000000

# %%
sns.set(font_scale=2)
plt.figure(figsize=(18,16))
sns.heatmap(df.corr(),annot=True)

# %%
df =pd.get_dummies(df,drop_first=True)

# %%
df
# Out:
#       column2  column3  column4  column5  column6  column7  column8  column9  \
# 0       0.350    0.265    0.090   0.2255   0.0995   0.0485   0.0700        7
# 1       0.530    0.420    0.135   0.6770   0.2565   0.1415   0.2100        9
# 2       0.440    0.365    0.125   0.5160   0.2155   0.1140   0.1550       10
# 3       0.330    0.255    0.080   0.2050   0.0895   0.0395   0.0550        7
# 4       0.425    0.300    0.095   0.3515   0.1410   0.0775   0.1200        8
# ...       ...      ...      ...      ...      ...      ...      ...      ...
# 4171    0.565    0.450    0.165   0.8870   0.3700   0.2390   0.2490       11
# 4172    0.590    0.440    0.135   0.9660   0.4390   0.2145   0.2605       10
# 4173    0.600    0.475    0.205   1.1760   0.5255   0.2875   0.3080        9
# 4174    0.625    0.485    0.150   1.0945   0.5310   0.2610   0.2960       10
# 4175    0.710    0.555    0.195   1.9485   0.9455   0.3765   0.4950       12
#
#       column1_I  column1_M
# 0             0          1
# 1             0          0
# 2             0          1
# 3             1          0
# 4             1          0
# ...         ...        ...
# 4171          0          0
# 4172          0          1
# 4173          0          1
# 4174          0          0
# 4175          0          1
#
# [4176 rows x 10 columns]

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split as tts
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error as mse
from sklearn.model_selection import train_test_split as tts
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor,BaggingRegressor
from sklearn.ensemble import VotingRegressor
from sklearn.metrics import r2_score,mean_absolute_error,mean_squared_log_error

# %%
df_x = df.drop('column9',axis=1)
df_y = df.column9

# %%
df_x = df_x.drop(['column1'],axis=1)

# %%
lr=LinearRegression()
aa = []
for i in range(0,100):
    x_train,x_test,y_train,y_test=tts(df_x,df_y,random_state=i,test_size=0.2)
    lr.fit(x_train,y_train)
    y_pred=lr.predict(x_test)
    rscore=r2_score(y_test,y_pred)
    aa.append(rscore)
    print('at r_state',i,"the r score is : ",rscore)
print("max---->",(aa.index(max(aa))))
# Out:
# at r_state 0 the r score is :  0.4927776383848287
# at r_state 1 the r score is :  0.549204861867548
# at r_state 2 the r score is :  0.5351565718313638
# at r_state 3 the r score is :  0.5061363684195804
# at r_state 4 the r score is :  0.5264233799990561
# at r_state 5 the r score is :  0.4450196997439928
# at r_state 6 the r score is :  0.45956213753498887
# at r_state 7 the r score is :  0.5085523229519402
# at r_state 8 the r score is :  0.5336346202946884
# at r_state 9 the r score is :  0.5637275140430642
# at r_state 10 the r score is :  0.5194364559989844
# at r_state 11 the r score is :  0.526645886724612
# at r_state 12 the r score is :  0.5520534316266028
# at r_state 13 the r score is :  0.5540040375613461
# at r_state 14 the r score is :  0.4712711147478752
# at r_state 15 the r score is :  0.5438410702709708
# at r_state 16 the r score is :  0.4887395498346162
# at r_state 17 the r score is :  0.5602817996527512
# at r_state 18 the r score is :  0.5412300425128862
# at r_state 19 the r score is :  0.45855978008490594
# at r_state 20 the r score is :  0.4454649353715976
# at r_state 21 the r score is :  0.5007373819050994
# at r_state 22 the r score is :  0.505091340638419
# at r_state 23 the r score is :  0.5058719565673688
# at r_state 24 the r score is :  0.4858609760576523
# at r_state 25 the r score is :  0.5525339970113383
# at r_state 26 the r score is :  0.574268291880669
# at r_state 27 the r score is :  0.48908877910952464
# at r_state 28 the r score is :  0.5597106942847767
# at r_state 29 the r score is :  0.5176657476904682
# at r_state 30 the r score is :  0.5544850074786691
# at r_state 31 the r score is :  0.578744948652834
# at r_state 32 the r score is :  0.5529389001808023
# at r_state 33 the r score is :  0.4952142767881563
# at r_state 34 the r score is :  0.5098432843053979
# at r_state 35 the r score is :  0.5524511936600913
# at r_state 36 the r score is :  0.4908522143273619
# at r_state 37 the r score is :  0.5426126125868889
# at r_state 38 the r score is :  0.5366158558301691
# at r_state 39 the r score is :  0.4686861593309378
# at r_state 40 the r score is :  0.49655348054636106
# at r_state 41 the r score is :  0.5195442776552729
# at r_state 42 the r score is :  0.5677128642588773
# at r_state 43 the r score is :  0.4830878607264262
# at r_state 44 the r score is :  0.5197753225284922
# at r_state 45 the r score is :  0.5364168137400873
# at r_state 46 the r score is :  0.5549213913687685
# at r_state 47 the r score is :  0.5018153862930004
# at r_state 48 the r score is :  0.491056911297036
# at r_state 49 the r score is :  0.5224725245952453
# at r_state 50 the r score is :  0.522723887336913
# at r_state 51 the r score is :  0.5126757707481682
# at r_state 52 the r score is :  0.48943517824779914
# at r_state 53 the r score is :  0.5062858179690188
# at r_state 54 the r score is :  0.5009393522879768
# at r_state 55 the r score is :  0.5385466129811968
# at r_state 56 the r score is :  0.5211736269887223
# at r_state 57 the r score is :  0.5179775481411708
# at r_state 58 the r score is :  0.5708269925141354
# at r_state 59 the r score is :  0.5703096424947489
# at r_state 60 the r score is :  0.49614384434648207
# at r_state 61 the r score is :  0.5387187551936375
# at r_state 62 the r score is :  0.5178851049398733
# at r_state 63 the r score is :  0.5181501803809033
# at r_state 64 the r score is :  0.4351695275135806
# at r_state 65 the r score is :  0.46760368576993794
# at r_state 66 the r score is :  0.5287405891038964
# at r_state 67 the r score is :  0.4677533185593524
# at r_state 68 the r score is :  0.5361061397168936
# at r_state 69 the r score is :  0.5436602439439544
# at r_state 70 the r score is :  0.5479431412274831
# at r_state 71 the r score is :  0.5527138393950709
# at r_state 72 the r score is :  0.49193395882258584
# at r_state 73 the r score is :  0.522139637947751
# at r_state 74 the r score is :  0.5461753445411615
# at r_state 75 the r score is :  0.4770640247279263
# at r_state 76 the r score is :  0.5312735533228531
# at r_state 77 the r score is :  0.5313859253348585
# at r_state 78 the r score is :  0.5334427151473655
# at r_state 79 the r score is :  0.45006080142529714
# at r_state 80 the r score is :  0.5607006442595278
# at r_state 81 the r score is :  0.475413757243874
# at r_state 82 the r score is :  0.523970860854573
# at r_state 83 the r score is :  0.5420471098615596
# at r_state 84 the r score is :  0.5579527943588258
# at r_state 85 the r score is :  0.44458519817929054
# at r_state 86 the r score is :  0.5253299764415973
# at r_state 87 the r score is :  0.47983128153472265
# at r_state 88 the r score is :  0.5459484776438407
# at r_state 89 the r score is :  0.5538792815380474
# at r_state 90 the r score is :  0.5388656360582944
# at r_state 91 the r score is :  0.4386740679090426
# at r_state 92 the r score is :  0.5122887175335721
# at r_state 93 the r score is :  0.5391762579513252
# at r_state 94 the r score is :  0.5174375147256703
# at r_state 95 the r score is :  0.5105306416333026
# at r_state 96 the r score is :  0.5139350188498923
# at r_state 97 the r score is :  0.510717728512111
# at r_state 98 the r score is :  0.5204794145290108
# at r_state 99 the r score is :  0.5329263991059244
# max----> 31

# %%
models_name = ['linear regression','KNN','SVM(rbf)','decision tree','RandomForest','AdaBoost',
                'gradientboost','bagging',]

# %%
model_list = [LinearRegression(),KNeighborsRegressor(),SVR(),DecisionTreeRegressor(), RandomForestRegressor(),
              AdaBoostRegressor(),GradientBoostingRegressor(),BaggingRegressor()]

# %%
results = pd.DataFrame(columns=['model','R2 Score','MAE','RMSE','mean error','median error','error score'])

# %%
from sklearn.model_selection import train_test_split,KFold,cross_val_score,GridSearchCV,RandomizedSearchCV

# %%
kfold = KFold(n_splits=5,shuffle=True,random_state=100)

for idx,model in enumerate(model_list):
    score=cross_val_score(model,df_x,df_y,cv=kfold,n_jobs=-1,verbose=1)
    x_train,x_test,y_train,y_test=train_test_split(df_x,df_y,random_state=42,test_size=0.15)
    model.fit(x_train,y_train)
    y_pred=model.predict(x_test)
    rscore=r2_score(y_test,y_pred)
    mse = mean_absolute_error(y_pred,y_test)
    rmse_scores = np.sqrt(-score)
    results.loc[idx] = [models_name[idx],rscore,mse,rmse_scores,score.mean(),np.median(score),score]

results
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.2s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    2.3s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/sklearn/svm/base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.1s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.4s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/sklearn/ensemble/forest.py:245: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.7s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.6s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of   5 | elapsed:    0.4s finished
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:10: RuntimeWarning: invalid value encountered in sqrt
#   # Remove the CWD from sys.path while we load stuff.
#                model  R2 Score       MAE                       RMSE  \
# 0  linear regression  0.586830  1.567080  [nan, nan, nan, nan, nan]
# 1                KNN  0.525558  1.627113  [nan, nan, nan, nan, nan]
# 2           SVM(rbf)  0.459310  1.627319  [nan, nan, nan, nan, nan]
# 3      decision tree  0.260981  1.988836  [nan, nan, nan, nan, nan]
# 4       RandomForest  0.519324  1.608453  [nan, nan, nan, nan, nan]
# 5           AdaBoost  0.285894  2.360589  [nan, nan, nan, nan, nan]
# 6      gradientboost  0.579829  1.519917  [nan, nan, nan, nan, nan]
# 7            bagging  0.499292  1.662839  [nan, nan, nan, nan, nan]
#
#    mean error  median error                                        error score
# 0    0.518331      0.524709  [0.5009066809527782, 0.5247093951261896, 0.460...
# 1    0.509085      0.511330  [0.4817139555951283, 0.5232287542788314, 0.485...
# 2    0.429926      0.429330  [0.41814672162270705, 0.4293297055421661, 0.40...
# 3    0.118934      0.126141  [0.12614108419425452, 0.17440624781760017, 0.0...
# 4    0.491625      0.507494  [0.4540528539446561, 0.5074940260329275, 0.467...
# 5    0.209456      0.203136  [0.17588733897262843, 0.21212100609977924, 0.3...
# 6    0.535541      0.544562  [0.49440991569755843, 0.5595116601362051, 0.53...
# 7    0.503071      0.513128  [0.4739132838493322, 0.5237331790904912, 0.486...

# %%
from sklearn.externals import joblib
joblib.dump(GradientBoostingRegressor(),'GBR_Project_3.pkl')
# Out:
# /home/sk-ji/anaconda3/lib/python3.7/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)
# ['GBR_Project_3.pkl']
